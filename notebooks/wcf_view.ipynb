# %%
# read in a tiff file and display using imshow

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = Image.open('./data/test8.tiff')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = Image.open('./data/test16.tiff')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=I;16 size=384x384>
